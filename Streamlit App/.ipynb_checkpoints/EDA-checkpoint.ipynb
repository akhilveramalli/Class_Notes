# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("patient_data.csv")
print(df.shape)        # rows, columns
df.head()
# Out:
# (101766, 25)
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0                 1                  41               0                1
# 1                 3                  59               0               18
# 2                 2                  11               5               13
# 3                 2                  44               1               16
# 4                 1                  51               0                8
#
#    number_outpatient  number_emergency  number_inpatient  number_diagnoses  \
# 0                  0                 0                 0                 1
# 1                  0                 0                 0                 9
# 2                  2                 0                 1                 6
# 3                  0                 0                 0                 7
# 4                  0                 0                 0                 5
#
#    gender             race  ...  max_glu_serum  diabetesMed  change insulin  \
# 0  Female        Caucasian  ...            NaN           No      No      No
# 1  Female        Caucasian  ...            NaN          Yes      Ch      Up
# 2  Female  AfricanAmerican  ...            NaN          Yes      No      No
# 3    Male        Caucasian  ...            NaN          Yes      Ch      Up
# 4    Male        Caucasian  ...            NaN          Yes      Ch  Steady
#
#   metformin glipizide glyburide pioglitazone rosiglitazone readmitted
# 0        No        No        No           No            No         NO
# 1        No        No        No           No            No        >30
# 2        No    Steady        No           No            No         NO
# 3        No        No        No           No            No         NO
# 4        No    Steady        No           No            No         NO
#
# [5 rows x 25 columns]

# %%
df.describe()
# Out:
#        time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# count     101766.000000       101766.000000   101766.000000    101766.000000
# mean           4.395987           43.095641        1.339730        16.021844
# std            2.985108           19.674362        1.705807         8.127566
# min            1.000000            1.000000        0.000000         1.000000
# 25%            2.000000           31.000000        0.000000        10.000000
# 50%            4.000000           44.000000        1.000000        15.000000
# 75%            6.000000           57.000000        2.000000        20.000000
# max           14.000000          132.000000        6.000000        81.000000
#
#        number_outpatient  number_emergency  number_inpatient  \
# count      101766.000000     101766.000000     101766.000000
# mean            0.369357          0.197836          0.635566
# std             1.267265          0.930472          1.262863
# min             0.000000          0.000000          0.000000
# 25%             0.000000          0.000000          0.000000
# 50%             0.000000          0.000000          0.000000
# 75%             0.000000          0.000000          1.000000
# max            42.000000         76.000000         21.000000
#
#        number_diagnoses  admission_type_id  discharge_disposition_id  \
# count     101766.000000      101766.000000             101766.000000
# mean           7.422607           2.024006                  3.715642
# std            1.933600           1.445403                  5.280166
# min            1.000000           1.000000                  1.000000
# 25%            6.000000           1.000000                  1.000000
# 50%            8.000000           1.000000                  1.000000
# 75%            9.000000           3.000000                  4.000000
# max           16.000000           8.000000                 28.000000
#
#        admission_source_id
# count        101766.000000
# mean              5.754437
# std               4.064081
# min               1.000000
# 25%               1.000000
# 50%               7.000000
# 75%               7.000000
# max              25.000000

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# max_glu_serum               96420
# A1Cresult                   84748
# race                         2273
# time_in_hospital                0
# age                             0
# rosiglitazone                   0
# pioglitazone                    0
# glyburide                       0
# glipizide                       0
# metformin                       0
# insulin                         0
# change                          0
# diabetesMed                     0
# admission_source_id             0
# num_lab_procedures              0
# discharge_disposition_id        0
# admission_type_id               0
# gender                          0
# number_diagnoses                0
# number_inpatient                0
# number_emergency                0
# number_outpatient               0
# num_medications                 0
# num_procedures                  0
# readmitted                      0
# dtype: int64

# %%
df['readmitted'].value_counts().reset_index()
# Out:
#   readmitted  count
# 0         NO  54864
# 1        >30  35545
# 2        <30  11357

# %%
df['readmitted'] = df['readmitted'].replace({
        '<30': 1,
        '>30': 0,
        'NO': 0
    })

# %%
fig = px.bar(df["readmitted"].value_counts().reset_index(),
             x="readmitted",
             y="count",
             title="Patient Readmission Distribution")
fig.update_layout(xaxis_title="Readmission",
                  yaxis_title="Count")
fig.show()

# %%
df["age"].value_counts().reset_index().sort_values(by="age")
# Out:
#         age  count
# 9    [0-10)    161
# 8   [10-20)    691
# 7   [20-30)   1657
# 5   [30-40)   3775
# 4   [40-50)   9685
# 2   [50-60)  17256
# 1   [60-70)  22483
# 0   [70-80)  26068
# 3   [80-90)  17197
# 6  [90-100)   2793

# %%
fig = px.bar(df["age"].value_counts().reset_index().sort_values(by="age"), x="age", y="count", title="Patient Age Distribution")
fig.update_layout(xaxis_title="Age Group",
                  yaxis_title="Count")
fig.show()

# %%
df['gender'].value_counts()
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: count, dtype: int64

# %%
fig = px.histogram(df, x="gender", title="Patient Gender Distribution")
fig.update_layout(xaxis_title="Gender",
                  yaxis_title="Count")
fig.show()

# %%
df['admission_type_id'].value_counts()
# Out:
# admission_type_id
# 1    53990
# 3    18869
# 2    18480
# 6     5291
# 5     4785
# 8      320
# 7       21
# 4       10
# Name: count, dtype: int64

# %%
fig = px.bar(df["admission_type_id"].value_counts().reset_index(),
             x="admission_type_id",
             y="count",
             title="Patient Admission Type Distribution")

fig.update_layout(xaxis_title="Admission Type",
                  yaxis_title="Count")

fig.show()

# %%
df['readmitted'].value_counts().reset_index()
# Out:
#   readmitted  count
# 0         NO  54864
# 1        >30  35545
# 2        <30  11357

# %%
fig = px.bar(df["readmitted"].value_counts().reset_index(),
             x="readmitted",
             y="count",
             title="Patient Readmission Distribution")
fig.update_layout(xaxis_title="Readmission",
                  yaxis_title="Count")
fig.show()

# %%
df['max_glu_serum'] = df['max_glu_serum'].fillna('NotMeasured')
df["max_glu_serum"].value_counts().reset_index().sort_values(by="max_glu_serum")
# Out:
#   max_glu_serum  count
# 2          >200   1485
# 3          >300   1264
# 1          Norm   2597
# 0   NotMeasured  96420

# %%
fig = px.bar(df["max_glu_serum"].value_counts().reset_index().sort_values(by="max_glu_serum"), x="max_glu_serum", y="count", title="max_glu_serum Distribution")
fig.update_layout(xaxis_title="max_glu_serum",
                  yaxis_title="Count")
fig.show()

# %%
df['A1Cresult'] = df['A1Cresult'].fillna('NotMeasured')
df["A1Cresult"].value_counts().reset_index().sort_values(by="A1Cresult")
# Out:
#      A1Cresult  count
# 3           >7   3812
# 1           >8   8216
# 2         Norm   4990
# 0  NotMeasured  84748

# %%
fig = px.bar(df["A1Cresult"].value_counts().reset_index().sort_values(by="A1Cresult"), x="A1Cresult", y="count", title="A1Cresult Distribution")
fig.update_layout(xaxis_title="A1Cresult",
                  yaxis_title="Count")
fig.show()

# %%
df['race'] = df['race'].fillna('Unknown')
df["race"].value_counts().reset_index().sort_values(by="race")
# Out:
#               race  count
# 1  AfricanAmerican  19210
# 5            Asian    641
# 0        Caucasian  76099
# 3         Hispanic   2037
# 4            Other   1506
# 2          Unknown   2273

# %%
fig = px.bar(df["race"].value_counts().reset_index().sort_values(by="race"), x="race", y="count", title="race Distribution")
fig.update_layout(xaxis_title="race",
                  yaxis_title="Count")
fig.show()

# %%
features = [
    'time_in_hospital',
    'num_lab_procedures',
    'num_procedures',
    'num_medications',
    'number_outpatient',
    'number_emergency',
    'number_inpatient',
    'number_diagnoses'
]

scatter_matrix(df[features], figsize=(12, 12))

plt.show()

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(12, 8))  
sns.heatmap(corr, annot=True, cmap='coolwarm', )
plt.title("Correlation Heatmap")
plt.show()
